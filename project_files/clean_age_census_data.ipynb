# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load
census_data = Path("../datasets/age_census_data.csv")

# %%
# Load csv as df
census_df = pd.read_csv(census_data)

# %%
# View df
census_df.head()
# Out:
#              Label (Grouping) Alabama!!Total!!Estimate  \
# 0            Total population                5,074,296
# 1                 SEX AND AGE                      NaN
# 2                        Male                    48.5%
# 3                      Female                    51.5%
# 4          Median age (years)                     39.6
#
#   Alabama!!Total!!Margin of Error Alabama!!60 years and over!!Estimate  \
# 0                           *****                            1,254,589
# 1                             NaN                                  NaN
# 2                            ±0.1                                44.9%
# 3                            ±0.1                                55.1%
# 4                            ±0.2                                 69.7
#
#   Alabama!!60 years and over!!Margin of Error Alaska!!Total!!Estimate  \
# 0                                      ±8,153                 733,583
# 1                                         NaN                     NaN
# 2                                        ±0.3                   52.6%
# 3                                        ±0.3                   47.4%
# 4                                        ±0.2                    35.9
#
#   Alaska!!Total!!Margin of Error Alaska!!60 years and over!!Estimate  \
# 0                          *****                             145,091
# 1                            NaN                                 NaN
# 2                           ±0.3                               51.2%
# 3                           ±0.3                               48.8%
# 4                           ±0.3                                68.5
#
#   Alaska!!60 years and over!!Margin of Error Arizona!!Total!!Estimate  ...  \
# 0                                     ±2,694                7,359,197  ...
# 1                                        NaN                      NaN  ...
# 2                                       ±0.8                    50.0%  ...
# 3                                       ±0.8                    50.0%  ...
# 4                                       ±0.4                     38.8  ...
#
#   Wisconsin!!60 years and over!!Estimate  \
# 0                              1,526,889
# 1                                    NaN
# 2                                  47.3%
# 3                                  52.7%
# 4                                   69.6
#
#   Wisconsin!!60 years and over!!Margin of Error Wyoming!!Total!!Estimate  \
# 0                                        ±6,815                  581,381
# 1                                           NaN                      NaN
# 2                                          ±0.2                    51.2%
# 3                                          ±0.2                    48.8%
# 4                                          ±0.2                     39.1
#
#   Wyoming!!Total!!Margin of Error Wyoming!!60 years and over!!Estimate  \
# 0                           *****                              146,340
# 1                             NaN                                  NaN
# 2                            ±0.4                                49.1%
# 3                            ±0.4                                50.9%
# 4                            ±0.5                                 69.5
#
#   Wyoming!!60 years and over!!Margin of Error Puerto Rico!!Total!!Estimate  \
# 0                                      ±2,749                          NaN
# 1                                         NaN                          NaN
# 2                                        ±0.9                          NaN
# 3                                        ±0.9                          NaN
# 4                                        ±0.3                          NaN
#
#   Puerto Rico!!Total!!Margin of Error  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   Puerto Rico!!60 years and over!!Estimate  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Puerto Rico!!60 years and over!!Margin of Error
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
# [5 rows x 209 columns]

# %%
# Drop all columns with margin in name
census_df.drop(census_df.filter(regex='Margin').columns, axis=1, inplace=True)
census_df.head()
# Out:
#              Label (Grouping) Alabama!!Total!!Estimate  \
# 0            Total population                5,074,296
# 1                 SEX AND AGE                      NaN
# 2                        Male                    48.5%
# 3                      Female                    51.5%
# 4          Median age (years)                     39.6
#
#   Alabama!!60 years and over!!Estimate Alaska!!Total!!Estimate  \
# 0                            1,254,589                 733,583
# 1                                  NaN                     NaN
# 2                                44.9%                   52.6%
# 3                                55.1%                   47.4%
# 4                                 69.7                    35.9
#
#   Alaska!!60 years and over!!Estimate Arizona!!Total!!Estimate  \
# 0                             145,091                7,359,197
# 1                                 NaN                      NaN
# 2                               51.2%                    50.0%
# 3                               48.8%                    50.0%
# 4                                68.5                     38.8
#
#   Arizona!!60 years and over!!Estimate Arkansas!!Total!!Estimate  \
# 0                            1,838,642                 3,045,637
# 1                                  NaN                       NaN
# 2                                46.5%                     49.4%
# 3                                53.5%                     50.6%
# 4                                 70.6                      38.9
#
#   Arkansas!!60 years and over!!Estimate California!!Total!!Estimate  ...  \
# 0                               738,823                  39,029,342  ...
# 1                                   NaN                         NaN  ...
# 2                                 46.1%                       50.1%  ...
# 3                                 53.9%                       49.9%  ...
# 4                                  69.9                        37.9  ...
#
#   Washington!!Total!!Estimate Washington!!60 years and over!!Estimate  \
# 0                   7,785,786                               1,789,686
# 1                         NaN                                     NaN
# 2                       50.5%                                   46.8%
# 3                       49.5%                                   53.2%
# 4                        38.4                                    69.9
#
#   West Virginia!!Total!!Estimate West Virginia!!60 years and over!!Estimate  \
# 0                      1,775,156                                    502,518
# 1                            NaN                                        NaN
# 2                          49.7%                                      46.5%
# 3                          50.3%                                      53.5%
# 4                           42.9                                       70.2
#
#   Wisconsin!!Total!!Estimate Wisconsin!!60 years and over!!Estimate  \
# 0                  5,892,539                              1,526,889
# 1                        NaN                                    NaN
# 2                      50.2%                                  47.3%
# 3                      49.8%                                  52.7%
# 4                       40.4                                   69.6
#
#   Wyoming!!Total!!Estimate Wyoming!!60 years and over!!Estimate  \
# 0                  581,381                              146,340
# 1                      NaN                                  NaN
# 2                    51.2%                                49.1%
# 3                    48.8%                                50.9%
# 4                     39.1                                 69.5
#
#   Puerto Rico!!Total!!Estimate Puerto Rico!!60 years and over!!Estimate
# 0                          NaN                                      NaN
# 1                          NaN                                      NaN
# 2                          NaN                                      NaN
# 3                          NaN                                      NaN
# 4                          NaN                                      NaN
#
# [5 rows x 105 columns]

# %%
# Rename the columns to be more readable 
renamed_census_df = census_df.rename(columns=lambda x: x.replace('!!60 years and over!!Estimate', '_60+_Estimate'))
renamed_census_df = renamed_census_df.rename(columns=lambda x: x.replace('!!Total!!Estimate', '_Total_Estimate'))
renamed_census_df = renamed_census_df.rename(columns={"Label (Grouping)": "Stat"})
renamed_census_df
# Out:
#                                                   Stat Alabama_Total_Estimate  \
# 0                                     Total population              5,074,296
# 1                                          SEX AND AGE                    NaN
# 2                                                 Male                  48.5%
# 3                                               Female                  51.5%
# 4                                   Median age (years)                   39.6
# ..                                                 ...                    ...
# 122      GROSS RENT AS A PERCENTAGE OF HOUSEHOLD IN...                    NaN
# 123                               Less than 30 percent                  57.3%
# 124                                 30 percent or more                  42.7%
# 125                                         GROSS RENT                    NaN
# 126                        Median gross rent (dollars)                    913
#
#     Alabama_60+_Estimate Alaska_Total_Estimate Alaska_60+_Estimate  \
# 0              1,254,589               733,583             145,091
# 1                    NaN                   NaN                 NaN
# 2                  44.9%                 52.6%               51.2%
# 3                  55.1%                 47.4%               48.8%
# 4                   69.7                  35.9                68.5
# ..                   ...                   ...                 ...
# 122                  NaN                   NaN                 NaN
# 123                55.2%                 60.7%               55.0%
# 124                44.8%                 39.3%               45.0%
# 125                  NaN                   NaN                 NaN
# 126                  741                 1,329               1,017
#
#     Arizona_Total_Estimate Arizona_60+_Estimate Arkansas_Total_Estimate  \
# 0                7,359,197            1,838,642               3,045,637
# 1                      NaN                  NaN                     NaN
# 2                    50.0%                46.5%                   49.4%
# 3                    50.0%                53.5%                   50.6%
# 4                     38.8                 70.6                    38.9
# ..                     ...                  ...                     ...
# 122                    NaN                  NaN                     NaN
# 123                  50.6%                44.2%                   59.6%
# 124                  49.4%                55.8%                   40.4%
# 125                    NaN                  NaN                     NaN
# 126                  1,450                1,202                     846
#
#     Arkansas_60+_Estimate California_Total_Estimate  ...  \
# 0                 738,823                39,029,342  ...
# 1                     NaN                       NaN  ...
# 2                   46.1%                     50.1%  ...
# 3                   53.9%                     49.9%  ...
# 4                    69.9                      37.9  ...
# ..                    ...                       ...  ...
# 122                   NaN                       NaN  ...
# 123                 51.2%                     46.9%  ...
# 124                 48.8%                     53.1%  ...
# 125                   NaN                       NaN  ...
# 126                   725                     1,870  ...
#
#     Washington_Total_Estimate Washington_60+_Estimate  \
# 0                   7,785,786               1,789,686
# 1                         NaN                     NaN
# 2                       50.5%                   46.8%
# 3                       49.5%                   53.2%
# 4                        38.4                    69.9
# ..                        ...                     ...
# 122                       NaN                     NaN
# 123                     51.4%                   42.8%
# 124                     48.6%                   57.2%
# 125                       NaN                     NaN
# 126                     1,630                   1,291
#
#     West Virginia_Total_Estimate West Virginia_60+_Estimate  \
# 0                      1,775,156                    502,518
# 1                            NaN                        NaN
# 2                          49.7%                      46.5%
# 3                          50.3%                      53.5%
# 4                           42.9                       70.2
# ..                           ...                        ...
# 122                          NaN                        NaN
# 123                        58.2%                      56.3%
# 124                        41.8%                      43.7%
# 125                          NaN                        NaN
# 126                          795                        674
#
#     Wisconsin_Total_Estimate Wisconsin_60+_Estimate Wyoming_Total_Estimate  \
# 0                  5,892,539              1,526,889                581,381
# 1                        NaN                    NaN                    NaN
# 2                      50.2%                  47.3%                  51.2%
# 3                      49.8%                  52.7%                  48.8%
# 4                       40.4                   69.6                   39.1
# ..                       ...                    ...                    ...
# 122                      NaN                    NaN                    NaN
# 123                    57.2%                  45.5%                  61.4%
# 124                    42.8%                  54.5%                  38.6%
# 125                      NaN                    NaN                    NaN
# 126                      992                    889                    895
#
#     Wyoming_60+_Estimate Puerto Rico_Total_Estimate Puerto Rico_60+_Estimate
# 0                146,340                        NaN                      NaN
# 1                    NaN                        NaN                      NaN
# 2                  49.1%                        NaN                      NaN
# 3                  50.9%                        NaN                      NaN
# 4                   69.5                        NaN                      NaN
# ..                   ...                        ...                      ...
# 122                  NaN                        NaN                      NaN
# 123                52.9%                        NaN                      NaN
# 124                47.1%                        NaN                      NaN
# 125                  NaN                        NaN                      NaN
# 126                  727                        NaN                      NaN
#
# [127 rows x 105 columns]

# %%
# Drop all columns with 60+ data
renamed_census_df.drop(renamed_census_df.filter(regex='60+').columns, axis=1, inplace=True)
renamed_census_df.head()
# Out:
#                          Stat Alabama_Total_Estimate Alaska_Total_Estimate  \
# 0            Total population              5,074,296               733,583
# 1                 SEX AND AGE                    NaN                   NaN
# 2                        Male                  48.5%                 52.6%
# 3                      Female                  51.5%                 47.4%
# 4          Median age (years)                   39.6                  35.9
#
#   Arizona_Total_Estimate Arkansas_Total_Estimate California_Total_Estimate  \
# 0              7,359,197               3,045,637                39,029,342
# 1                    NaN                     NaN                       NaN
# 2                  50.0%                   49.4%                     50.1%
# 3                  50.0%                   50.6%                     49.9%
# 4                   38.8                    38.9                      37.9
#
#   Colorado_Total_Estimate Connecticut_Total_Estimate Delaware_Total_Estimate  \
# 0               5,839,926                  3,626,205               1,018,396
# 1                     NaN                        NaN                     NaN
# 2                   50.7%                      49.0%                   48.6%
# 3                   49.3%                      51.0%                   51.4%
# 4                    37.7                       40.9                    41.5
#
#   District of Columbia_Total_Estimate  ... Tennessee_Total_Estimate  \
# 0                             671,803  ...                7,051,339
# 1                                 NaN  ...                      NaN
# 2                               47.6%  ...                    49.1%
# 3                               52.4%  ...                    50.9%
# 4                                34.9  ...                     39.2
#
#   Texas_Total_Estimate Utah_Total_Estimate Vermont_Total_Estimate  \
# 0           30,029,572           3,380,800                647,064
# 1                  NaN                 NaN                    NaN
# 2                50.0%               50.8%                  49.6%
# 3                50.0%               49.2%                  50.4%
# 4                 35.6                32.1                   43.2
#
#   Virginia_Total_Estimate Washington_Total_Estimate  \
# 0               8,683,619                 7,785,786
# 1                     NaN                       NaN
# 2                   49.5%                     50.5%
# 3                   50.5%                     49.5%
# 4                    39.0                      38.4
#
#   West Virginia_Total_Estimate Wisconsin_Total_Estimate  \
# 0                    1,775,156                5,892,539
# 1                          NaN                      NaN
# 2                        49.7%                    50.2%
# 3                        50.3%                    49.8%
# 4                         42.9                     40.4
#
#   Wyoming_Total_Estimate Puerto Rico_Total_Estimate
# 0                581,381                        NaN
# 1                    NaN                        NaN
# 2                  51.2%                        NaN
# 3                  48.8%                        NaN
# 4                   39.1                        NaN
#
# [5 rows x 53 columns]

# %%
# Filter out age and Total Pop rows
age_census_df = renamed_census_df.iloc[0:5]
row_to_delete = [1,2,3]
age_census_df.drop(renamed_census_df.index[row_to_delete], inplace=True)
age_census_df
# Out:
# /var/folders/6z/hrjcy3bn6djf_8b605nts_dh0000gp/T/ipykernel_21316/3367387354.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age_census_df.drop(renamed_census_df.index[row_to_delete], inplace=True)
#                          Stat Alabama_Total_Estimate Alaska_Total_Estimate  \
# 0            Total population              5,074,296               733,583
# 4          Median age (years)                   39.6                  35.9
#
#   Arizona_Total_Estimate Arkansas_Total_Estimate California_Total_Estimate  \
# 0              7,359,197               3,045,637                39,029,342
# 4                   38.8                    38.9                      37.9
#
#   Colorado_Total_Estimate Connecticut_Total_Estimate Delaware_Total_Estimate  \
# 0               5,839,926                  3,626,205               1,018,396
# 4                    37.7                       40.9                    41.5
#
#   District of Columbia_Total_Estimate  ... Tennessee_Total_Estimate  \
# 0                             671,803  ...                7,051,339
# 4                                34.9  ...                     39.2
#
#   Texas_Total_Estimate Utah_Total_Estimate Vermont_Total_Estimate  \
# 0           30,029,572           3,380,800                647,064
# 4                 35.6                32.1                   43.2
#
#   Virginia_Total_Estimate Washington_Total_Estimate  \
# 0               8,683,619                 7,785,786
# 4                    39.0                      38.4
#
#   West Virginia_Total_Estimate Wisconsin_Total_Estimate  \
# 0                    1,775,156                5,892,539
# 4                         42.9                     40.4
#
#   Wyoming_Total_Estimate Puerto Rico_Total_Estimate
# 0                581,381                        NaN
# 4                   39.1                        NaN
#
# [2 rows x 53 columns]

# %%
# Flip the rows and columns and reset the index
age_data_flipped = age_census_df.set_index('Stat').transpose()
age_data_flipped
# Out:
# Stat                                Total population  \
# Alabama_Total_Estimate                     5,074,296
# Alaska_Total_Estimate                        733,583
# Arizona_Total_Estimate                     7,359,197
# Arkansas_Total_Estimate                    3,045,637
# California_Total_Estimate                 39,029,342
# Colorado_Total_Estimate                    5,839,926
# Connecticut_Total_Estimate                 3,626,205
# Delaware_Total_Estimate                    1,018,396
# District of Columbia_Total_Estimate          671,803
# Florida_Total_Estimate                    22,244,823
# Georgia_Total_Estimate                    10,912,876
# Hawaii_Total_Estimate                      1,440,196
# Idaho_Total_Estimate                       1,939,033
# Illinois_Total_Estimate                   12,582,032
# Indiana_Total_Estimate                     6,833,037
# Iowa_Total_Estimate                        3,200,517
# Kansas_Total_Estimate                      2,937,150
# Kentucky_Total_Estimate                    4,512,310
# Louisiana_Total_Estimate                   4,590,241
# Maine_Total_Estimate                       1,385,340
# Maryland_Total_Estimate                    6,164,660
# Massachusetts_Total_Estimate               6,981,974
# Michigan_Total_Estimate                   10,034,118
# Minnesota_Total_Estimate                   5,717,184
# Mississippi_Total_Estimate                 2,940,057
# Missouri_Total_Estimate                    6,177,957
# Montana_Total_Estimate                     1,122,867
# Nebraska_Total_Estimate                    1,967,923
# Nevada_Total_Estimate                      3,177,772
# New Hampshire_Total_Estimate               1,395,231
# New Jersey_Total_Estimate                  9,261,699
# New Mexico_Total_Estimate                  2,113,344
# New York_Total_Estimate                   19,677,151
# North Carolina_Total_Estimate             10,698,973
# North Dakota_Total_Estimate                  779,261
# Ohio_Total_Estimate                       11,756,058
# Oklahoma_Total_Estimate                    4,019,800
# Oregon_Total_Estimate                      4,240,137
# Pennsylvania_Total_Estimate               12,972,008
# Rhode Island_Total_Estimate                1,093,734
# South Carolina_Total_Estimate              5,282,634
# South Dakota_Total_Estimate                  909,824
# Tennessee_Total_Estimate                   7,051,339
# Texas_Total_Estimate                      30,029,572
# Utah_Total_Estimate                        3,380,800
# Vermont_Total_Estimate                       647,064
# Virginia_Total_Estimate                    8,683,619
# Washington_Total_Estimate                  7,785,786
# West Virginia_Total_Estimate               1,775,156
# Wisconsin_Total_Estimate                   5,892,539
# Wyoming_Total_Estimate                       581,381
# Puerto Rico_Total_Estimate                       NaN
#
# Stat                                        Median age (years)
# Alabama_Total_Estimate                                    39.6
# Alaska_Total_Estimate                                     35.9
# Arizona_Total_Estimate                                    38.8
# Arkansas_Total_Estimate                                   38.9
# California_Total_Estimate                                 37.9
# Colorado_Total_Estimate                                   37.7
# Connecticut_Total_Estimate                                40.9
# Delaware_Total_Estimate                                   41.5
# District of Columbia_Total_Estimate                       34.9
# Florida_Total_Estimate                                    42.7
# Georgia_Total_Estimate                                    37.6
# Hawaii_Total_Estimate                                     40.8
# Idaho_Total_Estimate                                      37.5
# Illinois_Total_Estimate                                   39.1
# Indiana_Total_Estimate                                    38.2
# Iowa_Total_Estimate                                       38.9
# Kansas_Total_Estimate                                     37.6
# Kentucky_Total_Estimate                                   39.4
# Louisiana_Total_Estimate                                  38.2
# Maine_Total_Estimate                                      45.1
# Maryland_Total_Estimate                                   39.7
# Massachusetts_Total_Estimate                              40.3
# Michigan_Total_Estimate                                   40.3
# Minnesota_Total_Estimate                                  39.0
# Mississippi_Total_Estimate                                38.9
# Missouri_Total_Estimate                                   39.1
# Montana_Total_Estimate                                    40.2
# Nebraska_Total_Estimate                                   37.4
# Nevada_Total_Estimate                                     39.0
# New Hampshire_Total_Estimate                              43.3
# New Jersey_Total_Estimate                                 40.4
# New Mexico_Total_Estimate                                 39.4
# New York_Total_Estimate                                   40.0
# North Carolina_Total_Estimate                             39.2
# North Dakota_Total_Estimate                               36.2
# Ohio_Total_Estimate                                       39.9
# Oklahoma_Total_Estimate                                   37.1
# Oregon_Total_Estimate                                     40.5
# Pennsylvania_Total_Estimate                               40.9
# Rhode Island_Total_Estimate                               40.7
# South Carolina_Total_Estimate                             40.5
# South Dakota_Total_Estimate                               38.5
# Tennessee_Total_Estimate                                  39.2
# Texas_Total_Estimate                                      35.6
# Utah_Total_Estimate                                       32.1
# Vermont_Total_Estimate                                    43.2
# Virginia_Total_Estimate                                   39.0
# Washington_Total_Estimate                                 38.4
# West Virginia_Total_Estimate                              42.9
# Wisconsin_Total_Estimate                                  40.4
# Wyoming_Total_Estimate                                    39.1
# Puerto Rico_Total_Estimate                                 NaN

# %%
# Save .csv output
out_path = Path("../datasets/filtered_age_data.csv")
age_data_flipped.to_csv(out_path)
