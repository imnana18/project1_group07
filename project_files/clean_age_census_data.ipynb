# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load
census_data = Path("../datasets/age_census_data.csv")

# %%
# Load csv as df
census_df = pd.read_csv(census_data)

# %%
# View df
census_df.head()
# Out:
#              Label (Grouping) Alabama!!Total!!Estimate  \
# 0            Total population                5,074,296
# 1                 SEX AND AGE                      NaN
# 2                        Male                    48.5%
# 3                      Female                    51.5%
# 4          Median age (years)                     39.6
#
#   Alabama!!Total!!Margin of Error Alabama!!60 years and over!!Estimate  \
# 0                           *****                            1,254,589
# 1                             NaN                                  NaN
# 2                            ±0.1                                44.9%
# 3                            ±0.1                                55.1%
# 4                            ±0.2                                 69.7
#
#   Alabama!!60 years and over!!Margin of Error Alaska!!Total!!Estimate  \
# 0                                      ±8,153                 733,583
# 1                                         NaN                     NaN
# 2                                        ±0.3                   52.6%
# 3                                        ±0.3                   47.4%
# 4                                        ±0.2                    35.9
#
#   Alaska!!Total!!Margin of Error Alaska!!60 years and over!!Estimate  \
# 0                          *****                             145,091
# 1                            NaN                                 NaN
# 2                           ±0.3                               51.2%
# 3                           ±0.3                               48.8%
# 4                           ±0.3                                68.5
#
#   Alaska!!60 years and over!!Margin of Error Arizona!!Total!!Estimate  ...  \
# 0                                     ±2,694                7,359,197  ...
# 1                                        NaN                      NaN  ...
# 2                                       ±0.8                    50.0%  ...
# 3                                       ±0.8                    50.0%  ...
# 4                                       ±0.4                     38.8  ...
#
#   Wisconsin!!60 years and over!!Estimate  \
# 0                              1,526,889
# 1                                    NaN
# 2                                  47.3%
# 3                                  52.7%
# 4                                   69.6
#
#   Wisconsin!!60 years and over!!Margin of Error Wyoming!!Total!!Estimate  \
# 0                                        ±6,815                  581,381
# 1                                           NaN                      NaN
# 2                                          ±0.2                    51.2%
# 3                                          ±0.2                    48.8%
# 4                                          ±0.2                     39.1
#
#   Wyoming!!Total!!Margin of Error Wyoming!!60 years and over!!Estimate  \
# 0                           *****                              146,340
# 1                             NaN                                  NaN
# 2                            ±0.4                                49.1%
# 3                            ±0.4                                50.9%
# 4                            ±0.5                                 69.5
#
#   Wyoming!!60 years and over!!Margin of Error Puerto Rico!!Total!!Estimate  \
# 0                                      ±2,749                          NaN
# 1                                         NaN                          NaN
# 2                                        ±0.9                          NaN
# 3                                        ±0.9                          NaN
# 4                                        ±0.3                          NaN
#
#   Puerto Rico!!Total!!Margin of Error  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   Puerto Rico!!60 years and over!!Estimate  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Puerto Rico!!60 years and over!!Margin of Error
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
# [5 rows x 209 columns]

# %%
# Drop all columns with margin in name
census_df.drop(census_df.filter(regex='Margin').columns, axis=1, inplace=True)
census_df.head()
# Out:
#              Label (Grouping) Alabama!!Total!!Estimate  \
# 0            Total population                5,074,296
# 1                 SEX AND AGE                      NaN
# 2                        Male                    48.5%
# 3                      Female                    51.5%
# 4          Median age (years)                     39.6
#
#   Alabama!!60 years and over!!Estimate Alaska!!Total!!Estimate  \
# 0                            1,254,589                 733,583
# 1                                  NaN                     NaN
# 2                                44.9%                   52.6%
# 3                                55.1%                   47.4%
# 4                                 69.7                    35.9
#
#   Alaska!!60 years and over!!Estimate Arizona!!Total!!Estimate  \
# 0                             145,091                7,359,197
# 1                                 NaN                      NaN
# 2                               51.2%                    50.0%
# 3                               48.8%                    50.0%
# 4                                68.5                     38.8
#
#   Arizona!!60 years and over!!Estimate Arkansas!!Total!!Estimate  \
# 0                            1,838,642                 3,045,637
# 1                                  NaN                       NaN
# 2                                46.5%                     49.4%
# 3                                53.5%                     50.6%
# 4                                 70.6                      38.9
#
#   Arkansas!!60 years and over!!Estimate California!!Total!!Estimate  ...  \
# 0                               738,823                  39,029,342  ...
# 1                                   NaN                         NaN  ...
# 2                                 46.1%                       50.1%  ...
# 3                                 53.9%                       49.9%  ...
# 4                                  69.9                        37.9  ...
#
#   Washington!!Total!!Estimate Washington!!60 years and over!!Estimate  \
# 0                   7,785,786                               1,789,686
# 1                         NaN                                     NaN
# 2                       50.5%                                   46.8%
# 3                       49.5%                                   53.2%
# 4                        38.4                                    69.9
#
#   West Virginia!!Total!!Estimate West Virginia!!60 years and over!!Estimate  \
# 0                      1,775,156                                    502,518
# 1                            NaN                                        NaN
# 2                          49.7%                                      46.5%
# 3                          50.3%                                      53.5%
# 4                           42.9                                       70.2
#
#   Wisconsin!!Total!!Estimate Wisconsin!!60 years and over!!Estimate  \
# 0                  5,892,539                              1,526,889
# 1                        NaN                                    NaN
# 2                      50.2%                                  47.3%
# 3                      49.8%                                  52.7%
# 4                       40.4                                   69.6
#
#   Wyoming!!Total!!Estimate Wyoming!!60 years and over!!Estimate  \
# 0                  581,381                              146,340
# 1                      NaN                                  NaN
# 2                    51.2%                                49.1%
# 3                    48.8%                                50.9%
# 4                     39.1                                 69.5
#
#   Puerto Rico!!Total!!Estimate Puerto Rico!!60 years and over!!Estimate
# 0                          NaN                                      NaN
# 1                          NaN                                      NaN
# 2                          NaN                                      NaN
# 3                          NaN                                      NaN
# 4                          NaN                                      NaN
#
# [5 rows x 105 columns]

# %%
# Rename the columns to be more readable 
renamed_census_df = census_df.rename(columns=lambda x: x.replace('!!60 years and over!!Estimate', '_60+_Estimate'))
renamed_census_df = renamed_census_df.rename(columns=lambda x: x.replace('!!Total!!Estimate', '_Total_Estimate'))
renamed_census_df = renamed_census_df.rename(columns={"Label (Grouping)": "Stat"})
renamed_census_df
# Out:
#                                                   Stat Alabama_Total_Estimate  \
# 0                                     Total population              5,074,296
# 1                                          SEX AND AGE                    NaN
# 2                                                 Male                  48.5%
# 3                                               Female                  51.5%
# 4                                   Median age (years)                   39.6
# ..                                                 ...                    ...
# 122      GROSS RENT AS A PERCENTAGE OF HOUSEHOLD IN...                    NaN
# 123                               Less than 30 percent                  57.3%
# 124                                 30 percent or more                  42.7%
# 125                                         GROSS RENT                    NaN
# 126                        Median gross rent (dollars)                    913
#
#     Alabama_60+_Estimate Alaska_Total_Estimate Alaska_60+_Estimate  \
# 0              1,254,589               733,583             145,091
# 1                    NaN                   NaN                 NaN
# 2                  44.9%                 52.6%               51.2%
# 3                  55.1%                 47.4%               48.8%
# 4                   69.7                  35.9                68.5
# ..                   ...                   ...                 ...
# 122                  NaN                   NaN                 NaN
# 123                55.2%                 60.7%               55.0%
# 124                44.8%                 39.3%               45.0%
# 125                  NaN                   NaN                 NaN
# 126                  741                 1,329               1,017
#
#     Arizona_Total_Estimate Arizona_60+_Estimate Arkansas_Total_Estimate  \
# 0                7,359,197            1,838,642               3,045,637
# 1                      NaN                  NaN                     NaN
# 2                    50.0%                46.5%                   49.4%
# 3                    50.0%                53.5%                   50.6%
# 4                     38.8                 70.6                    38.9
# ..                     ...                  ...                     ...
# 122                    NaN                  NaN                     NaN
# 123                  50.6%                44.2%                   59.6%
# 124                  49.4%                55.8%                   40.4%
# 125                    NaN                  NaN                     NaN
# 126                  1,450                1,202                     846
#
#     Arkansas_60+_Estimate California_Total_Estimate  ...  \
# 0                 738,823                39,029,342  ...
# 1                     NaN                       NaN  ...
# 2                   46.1%                     50.1%  ...
# 3                   53.9%                     49.9%  ...
# 4                    69.9                      37.9  ...
# ..                    ...                       ...  ...
# 122                   NaN                       NaN  ...
# 123                 51.2%                     46.9%  ...
# 124                 48.8%                     53.1%  ...
# 125                   NaN                       NaN  ...
# 126                   725                     1,870  ...
#
#     Washington_Total_Estimate Washington_60+_Estimate  \
# 0                   7,785,786               1,789,686
# 1                         NaN                     NaN
# 2                       50.5%                   46.8%
# 3                       49.5%                   53.2%
# 4                        38.4                    69.9
# ..                        ...                     ...
# 122                       NaN                     NaN
# 123                     51.4%                   42.8%
# 124                     48.6%                   57.2%
# 125                       NaN                     NaN
# 126                     1,630                   1,291
#
#     West Virginia_Total_Estimate West Virginia_60+_Estimate  \
# 0                      1,775,156                    502,518
# 1                            NaN                        NaN
# 2                          49.7%                      46.5%
# 3                          50.3%                      53.5%
# 4                           42.9                       70.2
# ..                           ...                        ...
# 122                          NaN                        NaN
# 123                        58.2%                      56.3%
# 124                        41.8%                      43.7%
# 125                          NaN                        NaN
# 126                          795                        674
#
#     Wisconsin_Total_Estimate Wisconsin_60+_Estimate Wyoming_Total_Estimate  \
# 0                  5,892,539              1,526,889                581,381
# 1                        NaN                    NaN                    NaN
# 2                      50.2%                  47.3%                  51.2%
# 3                      49.8%                  52.7%                  48.8%
# 4                       40.4                   69.6                   39.1
# ..                       ...                    ...                    ...
# 122                      NaN                    NaN                    NaN
# 123                    57.2%                  45.5%                  61.4%
# 124                    42.8%                  54.5%                  38.6%
# 125                      NaN                    NaN                    NaN
# 126                      992                    889                    895
#
#     Wyoming_60+_Estimate Puerto Rico_Total_Estimate Puerto Rico_60+_Estimate
# 0                146,340                        NaN                      NaN
# 1                    NaN                        NaN                      NaN
# 2                  49.1%                        NaN                      NaN
# 3                  50.9%                        NaN                      NaN
# 4                   69.5                        NaN                      NaN
# ..                   ...                        ...                      ...
# 122                  NaN                        NaN                      NaN
# 123                52.9%                        NaN                      NaN
# 124                47.1%                        NaN                      NaN
# 125                  NaN                        NaN                      NaN
# 126                  727                        NaN                      NaN
#
# [127 rows x 105 columns]

# %%
# Filter out age and Total Pop rows
age_census_df = renamed_census_df.iloc[0:5]
row_to_delete = [1,2,3]
age_census_df.drop(renamed_census_df.index[row_to_delete], inplace=True)
age_census_df
# Out:
# /var/folders/6z/hrjcy3bn6djf_8b605nts_dh0000gp/T/ipykernel_33118/3367387354.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age_census_df.drop(renamed_census_df.index[row_to_delete], inplace=True)
#                          Stat Alabama_Total_Estimate Alabama_60+_Estimate  \
# 0            Total population              5,074,296            1,254,589
# 4          Median age (years)                   39.6                 69.7
#
#   Alaska_Total_Estimate Alaska_60+_Estimate Arizona_Total_Estimate  \
# 0               733,583             145,091              7,359,197
# 4                  35.9                68.5                   38.8
#
#   Arizona_60+_Estimate Arkansas_Total_Estimate Arkansas_60+_Estimate  \
# 0            1,838,642               3,045,637               738,823
# 4                 70.6                    38.9                  69.9
#
#   California_Total_Estimate  ... Washington_Total_Estimate  \
# 0                39,029,342  ...                 7,785,786
# 4                      37.9  ...                      38.4
#
#   Washington_60+_Estimate West Virginia_Total_Estimate  \
# 0               1,789,686                    1,775,156
# 4                    69.9                         42.9
#
#   West Virginia_60+_Estimate Wisconsin_Total_Estimate Wisconsin_60+_Estimate  \
# 0                    502,518                5,892,539              1,526,889
# 4                       70.2                     40.4                   69.6
#
#   Wyoming_Total_Estimate Wyoming_60+_Estimate Puerto Rico_Total_Estimate  \
# 0                581,381              146,340                        NaN
# 4                   39.1                 69.5                        NaN
#
#   Puerto Rico_60+_Estimate
# 0                      NaN
# 4                      NaN
#
# [2 rows x 105 columns]

# %%
# Save .csv output
out_path = Path("../datasets/filtered_age_data.csv")
age_census_df.to_csv(out_path)
